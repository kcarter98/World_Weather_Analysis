# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0     Ushuaia      AR -54.8000  -68.3000     37.06        87
# 1        1    Portland      US  45.5234 -122.6762     66.78        75
# 2        2     Mataura      NZ -46.1927  168.8643     41.49        93
# 3        3  Port Hardy      CA  50.6996 -127.4199     55.40        93
# 4        4       Bluff      NZ -46.6000  168.3333     41.81        84
#
#    Cloudiness  Wind Speed Current Description
# 0          90        9.22          light rain
# 1           1        4.00           clear sky
# 2         100        3.67     overcast clouds
# 3          40        4.61    scattered clouds
# 4          99       12.35     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min = input("What is the minimum temperature you would like for your stay?")
max = input("What is the maximum temperature you would like for your stay?")
# Out:
# What is the minimum temperature you would like for your stay?70
# What is the maximum temperature you would like for your stay?80

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
suitable_cities_df = city_data_df.loc[(city_data_df["Max Temp"] >= float(min)) & (city_data_df["Max Temp"] <= float(max))]
suitable_cities_df.head()
# Out:
#     City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 7         7       Rikitea      PF -23.1203 -134.9692     71.08        69
# 10       10  Puerto Ayora      EC  -0.7393  -90.3518     72.55        92
# 15       15       Cayenne      GF   4.9333  -52.3333     76.08        91
# 21       21    Sao Filipe      CV  14.8961  -24.4956     72.34        83
# 39       39        Avarua      CK -21.2078 -159.7750     77.05        83
#
#     Cloudiness  Wind Speed Current Description
# 7          100       25.37          light rain
# 10         100        5.99     overcast clouds
# 15           0        0.00           clear sky
# 21          58        4.47       broken clouds
# 39          40       12.66    scattered clouds

# %%
# 4a. Determine if there are any empty rows.
suitable_cities_df.count()
# Out:
# City_ID                206
# City                   206
# Country                206
# Lat                    206
# Lng                    206
# Max Temp               206
# Humidity               206
# Cloudiness             206
# Wind Speed             206
# Current Description    206
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
# No Empty Rows

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = suitable_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = pd.NaT

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    params["location"] = f"{lat},{lng}"

    # 6e. Make request and retrieve the JSON data from the search. 
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_name = hotels["results"][0]["name"]
        hotel_df.loc[index, "Hotel Name"] = hotel_name
        print(f"Hotel {index}:{hotel_name} Found!")
    except (IndexError):
        print(f"Hotel {index}:{hotel_name} Not Found...")
        pass
     
print("End of Search!")
# Out:
# Hotel 7:People ThankYou Found!
# Hotel 10:Finch Bay Galapagos Hotel Found!
# Hotel 15:Hôtel Le Dronmi Found!
# Hotel 21:Hotel Xaguate Found!
# Hotel 39:Paradise Inn Found!
# Hotel 40:Hotel Zaraza Found!
# Hotel 43:Villa Enata Found!
# Hotel 45:American Eagle Inn Found!
# Hotel 48:ibis Styles Mt Isa Verona Found!
# Hotel 50:Hampton Inn & Suites Morgan City Found!
# Hotel 57:Yalemd Found!
# Hotel 58:Shephard's Beach Resort Found!
# Hotel 60:Hospitality Carnarvon Found!
# Hotel 61:Six Acres Bed & Breakfast Found!
# Hotel 63:La Quinta Inn & Suites by Wyndham Stephenville Found!
# Hotel 67:Baza Otdykha "Medvezhiy Ugol" Found!
# Hotel 77:KD Travellers Home Found!
# Hotel 79:Desert Palms Alice Springs Found!
# Hotel 82:Shanti Maurice Resort & Spa Found!
# Hotel 83:Reno Motel Found!
# Hotel 84:Americas Best Value Inn & Suites Harrisonville Found!
# Hotel 87:Grand Hotel Cirta Found!
# Hotel 89:Aldea del Bazar Hotel and Spa Found!
# Hotel 90:Hawaiian Princess Resort Found!
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 7           Rikitea      PF     71.08          light rain -23.1203 -134.9692
# 10     Puerto Ayora      EC     72.55     overcast clouds  -0.7393  -90.3518
# 15          Cayenne      GF     76.08           clear sky   4.9333  -52.3333
# 21       Sao Filipe      CV     72.34       broken clouds  14.8961  -24.4956
# 39           Avarua      CK     77.05    scattered clouds -21.2078 -159.7750
# ..              ...     ...       ...                 ...      ...       ...
# 656      Washington      US     73.80           clear sky  47.5001 -120.5015
# 658     Carson City      US     72.43                haze  39.1638 -119.7674
# 668             Soe      ID     78.24     overcast clouds  -9.8607  124.2840
# 675  Gornopravdinsk      RU     77.86    scattered clouds  60.0500   69.9000
# 680     Salinopolis      BR     77.99           clear sky  -0.6136  -47.3561
#
# ...

# %%
# 8a. Create the output File (CSV)
output_data_file = 'WeatherPy_vacation.csv'
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
#Saved to WeatherPy_vacation_map.PNG
# Out:
# Figure(layout=FigureLayout(height='420px'))
